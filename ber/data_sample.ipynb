# %%
# installation of required libraries and dependencies
# numeric calculations
! pip install numpy==1.26.0 
# data frames 
! pip install pandas==2.1.1 
# machine learning algorithms 
! pip install scikit-learn==1.5.1 
! pip install scipy==1.12.0
# plotting 
! pip install plotly==5.24.1 
! pip install matplotlib==3.8.0 
! pip install seaborn==0.13.2 
! pip install plotly-express==0.4.1 
! pip install chart-studio==1.1.0 
# web app library 
! pip install streamlit==1.37.1 
# association rules
! pip install mlxtend==0.23.3 

! pip install nbformat==5.9.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp39-cp39-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\bdosanjosg\\AppData\\Roaming\\Python\\Python39\\site-packages\\~umpy.libs\\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==2.1.1
#   Downloading pandas-2.1.1-cp39-cp39-win_amd64.whl (10.8 MB)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas==2.1.1) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas==2.1.1) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas==2.1.1) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas==2.1.1) (1.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas==2.1.1) (1.17.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\bdosanjosg\\AppData\\Roaming\\Python\\Python39\\site-packages\\~andas.libs\\msvcp140-0f2ea95580b32bcfc81c235d5751ce78.dll'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn==1.5.1
#   Downloading scikit_learn-1.5.1-cp39-cp39-win_amd64.whl (11.0 MB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from scikit-learn==1.5.1) (1.26.0)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.1 scipy-1.13.1 threadpoolctl-3.5.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy==1.12.0
#   Downloading scipy-1.12.0-cp39-cp39-win_amd64.whl (46.2 MB)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from scipy==1.12.0) (1.26.0)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# Successfully installed scipy-1.12.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly==5.24.1
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Requirement already satisfied: packaging in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly==5.24.1) (24.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.1 tenacity-9.0.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib==3.8.0
#   Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib==3.8.0) (1.26.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.3-cp39-cp39-win_amd64.whl (2.2 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib==3.8.0) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib==3.8.0) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=6.2.0
#   Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib==3.8.0) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib==3.8.0) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.55.3 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.8.0 pillow-11.1.0 pyparsing-3.2.1
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn==0.13.2
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from seaborn==0.13.2) (2.1.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from seaborn==0.13.2) (1.26.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from seaborn==0.13.2) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.55.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly-express==0.4.1
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly-express==0.4.1) (2.1.1)
# Requirement already satisfied: scipy>=0.18 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly-express==0.4.1) (1.12.0)
# Requirement already satisfied: numpy>=1.11 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly-express==0.4.1) (1.26.0)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.4-cp39-cp39-win_amd64.whl (9.9 MB)
# Collecting patsy>=0.5
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly-express==0.4.1) (5.24.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=0.20.0->plotly-express==0.4.1) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=0.20.0->plotly-express==0.4.1) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=0.20.0->plotly-express==0.4.1) (2.9.0.post0)
# Requirement already satisfied: packaging in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly>=4.1.0->plotly-express==0.4.1) (24.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly>=4.1.0->plotly-express==0.4.1) (9.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly-express==0.4.1) (1.17.0)
# Installing collected packages: patsy, statsmodels, plotly-express
# Successfully installed patsy-1.0.1 plotly-express-0.4.1 statsmodels-0.14.4
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting chart-studio==1.1.0
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: plotly in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from chart-studio==1.1.0) (5.24.1)
# Requirement already satisfied: six in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from chart-studio==1.1.0) (1.17.0)
# Requirement already satisfied: requests in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from chart-studio==1.1.0) (2.32.3)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly->chart-studio==1.1.0) (9.0.0)
# Requirement already satisfied: packaging in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from plotly->chart-studio==1.1.0) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests->chart-studio==1.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests->chart-studio==1.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests->chart-studio==1.1.0) (2024.12.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests->chart-studio==1.1.0) (3.10)
# Installing collected packages: retrying, chart-studio
# Successfully installed chart-studio-1.1.0 retrying-1.3.4
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit==1.37.1
#   Downloading streamlit-1.37.1-py2.py3-none-any.whl (8.7 MB)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (2.1.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (6.4.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (24.2)
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (2.32.3)
# Collecting watchdog<5,>=2.1.5
#   Downloading watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-19.0.0-cp39-cp39-win_amd64.whl (25.5 MB)
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting protobuf<6,>=3.20
#   Downloading protobuf-5.29.3-cp39-cp39-win_amd64.whl (434 kB)
# Collecting pillow<11,>=7.1.0
#   Downloading pillow-10.4.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (4.12.2)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from streamlit==1.37.1) (1.26.0)
# Collecting altair<6,>=4.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting narwhals>=1.14.2
#   Downloading narwhals-1.23.0-py3-none-any.whl (306 kB)
# Requirement already satisfied: jinja2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from altair<6,>=4.0->streamlit==1.37.1) (3.1.5)
# Requirement already satisfied: colorama in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from click<9,>=7.0->streamlit==1.37.1) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.22.3-cp39-cp39-win_amd64.whl (231 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.3.0->streamlit==1.37.1) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.3.0->streamlit==1.37.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.3.0->streamlit==1.37.1) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.37.1) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit==1.37.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit==1.37.1) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit==1.37.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit==1.37.1) (2024.12.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit==1.37.1) (3.10)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from rich<14,>=10.14.0->streamlit==1.37.1) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: rpds-py, attrs, referencing, smmap, mdurl, jsonschema-specifications, narwhals, markdown-it-py, jsonschema, gitdb, watchdog, toml, tenacity, rich, pydeck, pyarrow, protobuf, pillow, gitpython, click, cachetools, blinker, altair, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# Successfully installed altair-5.5.0 attrs-24.3.0 blinker-1.9.0 cachetools-5.5.0 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.23.0 pillow-10.4.0 protobuf-5.29.3 pyarrow-19.0.0 pydeck-0.9.1 referencing-0.36.1 rich-13.9.4 rpds-py-0.22.3 smmap-5.0.2 streamlit-1.37.1 tenacity-8.5.0 toml-0.10.2 watchdog-4.0.2
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend==0.23.3
#   Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (1.26.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (2.1.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (1.5.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (1.4.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from mlxtend==0.23.3) (1.12.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (4.55.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (10.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3) (24.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend==0.23.3) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=0.24.2->mlxtend==0.23.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from pandas>=0.24.2->mlxtend==0.23.3) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend==0.23.3) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from scikit-learn>=1.3.1->mlxtend==0.23.3) (3.5.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.3
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nbformat==5.9.2
#   Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: traitlets>=5.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from nbformat==5.9.2) (5.14.3)
# Requirement already satisfied: jupyter-core in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from nbformat==5.9.2) (5.7.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from nbformat==5.9.2) (4.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jsonschema>=2.6->nbformat==5.9.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jsonschema>=2.6->nbformat==5.9.2) (0.36.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jsonschema>=2.6->nbformat==5.9.2) (24.3.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jsonschema>=2.6->nbformat==5.9.2) (0.22.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat==5.9.2) (4.12.2)
# Requirement already satisfied: pywin32>=300 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat==5.9.2) (308)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\bdosanjosg\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat==5.9.2) (4.3.6)
# Installing collected packages: fastjsonschema, nbformat
# Successfully installed fastjsonschema-2.21.1 nbformat-5.9.2
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# load pandas to deal with the data
import pandas as pd
# plotting
import matplotlib.pyplot as plt
import seaborn as sns
import folium

import numpy as np

# %%
# load data from table file where entries are separated with a space
data_cleaned = pd.read_table("./data/cleaned-data-rafa.csv", sep=",")
# show first 5 rows of the dataframe
data_cleaned.head()
# Out:
#            id          user        lat      long  \
# 0  4395181099  30624617@N03  45.754858  4.821710
# 1  4394748717  35853470@N00  45.753270  4.862953
# 2  4394694699  11817998@N05  45.760655  4.846564
# 3  4394803790  11545749@N06  45.784000  4.874072
# 4  4394803554  11545749@N06  45.784000  4.874072
#
#                                                 tags  \
# 0                 chair,lyon,rhône,chaise,rhônealpes
# 1                                                NaN
# 2                                         365,iphone
# 3       nin,nineinchnails,gift,screening,toiou,avott
# 4  lyon,nin,nineinchnails,gift,screening,toiou,avott
#
#                          title  date_taken_minute  date_taken_hour  \
# 0             Chaises avec vue               11.0               15
# 1                          NaN               51.0               17
# 2       59/365 - R46 V103 B163               29.0               17
# 3  2010-01-29 Toiou Avott Lyon               15.0               20
# 4  2010-01-28 Toiou Avott Lyon               10.0               20
#
#    date_taken_day  date_taken_month  date_taken_year  date_upload_minute  \
# 0              28                 2             2010                  23
# 1              28                 2             2010                  52
# 2              28                 2             2010                  33
# 3              28                 1             2010                  38
# 4              28                 1             2010                  38
#
#    date_upload_hour  date_upload_day  date_upload_month  date_upload_year  \
# 0                20             28.0                  2            2010.0
# 1                17             28.0                  2            2010.0
# 2                17             28.0                  2            2010.0
# 3                12             28.0                  2            2010.0
# 4                12             28.0                  2            2010.0
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %% [markdown]
# ## WORKING WITH A SAMPLE DATA ##

# %%
data_sample = data_cleaned.sample(5000)

# %%
#To check the missing values
data_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 128029 to 149877
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  10000 non-null  int64
#  1   user                10000 non-null  object
#  2   lat                 10000 non-null  float64
#  3   long                10000 non-null  float64
#  4   tags                7486 non-null   object
#  5   title               9086 non-null   object
#  6   date_taken_minute   10000 non-null  float64
#  7   date_taken_hour     10000 non-null  int64
#  8   date_taken_day      10000 non-null  int64
#  9   date_taken_month    10000 non-null  int64
#  10  date_taken_year     10000 non-null  int64
#  11  date_upload_minute  10000 non-null  int64
#  12  date_upload_hour    10000 non-null  int64
#  13  date_upload_day     10000 non-null  float64
#  14  date_upload_month   10000 non-null  int64
#  15  date_upload_year    10000 non-null  float64
#  16  Unnamed: 16         0 non-null      float64
#  17  Unnamed: 17         0 non-null      float64
#  18  Unnamed: 18         0 non-null      float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.5+ MB

# %%
#Visualizing the position in the map of pictures
photo_locations = data_sample[['lat', 'long']]

map = folium.Map(location=[photo_locations['lat'].mean(), photo_locations['long'].mean()], zoom_start=2, control_scale=True)

for i in range(0, len(photo_locations)):
    folium.Marker([photo_locations.iloc[i]['lat'], photo_locations.iloc[i]['long']]).add_to(map)

# %%
#Save the map
map.save('map_sample.html')

# %%
map

# %%
#Looking for pictures outside of lyon

max_lat = data_cleaned['lat'].max()
min_lat = data_cleaned['lat'].min()
max_long = data_cleaned['long'].max()
min_long = data_cleaned['long'].min()

print(f"Max Latitude: {max_lat}, Min Latitude: {min_lat}")
print(f"Max Longitude: {max_long}, Min Longitude: {min_long}")

data_cleaned['lat']
max_lat_row = data_cleaned[data_cleaned['lat'] == max_lat]
min_lat_row = data_cleaned[data_cleaned['lat'] == min_lat]
max_long_row = data_cleaned[data_cleaned['long'] == max_long]
min_long_row = data_cleaned[data_cleaned['long'] == min_long]

max_lat_row
min_lat_row
max_long_row
min_long_row

#Removing the pictures outside of Lyon
data_lyon = data_cleaned[(data_cleaned['lat'] >= 45.7) & (data_cleaned['lat'] <= 45.8) & (data_cleaned['long'] >= 4.7) & (data_cleaned['long'] <= 4.9)]
# Out:
# Max Latitude: 45.85495, Min Latitude: 45.6552
# Max Longitude: 5.006709, Min Longitude: 4.720312

# %%
#Map of Lyon
lyon_coords = [45.76, 4.85]

map_lyon = folium.Map(location=lyon_coords, zoom_start=13, control_scale=True)

for i in range(0, len(points_outside_lyon)):
    folium.Marker([points_outside_lyon.iloc[i]['lat'], points_outside_lyon.iloc[i]['long']]).add_to(map_lyon)

# %% [markdown]
# ## Task #1: Prepare Data for Clustering

# %%
# we will keep only the lat and long columns for clustering

#Columns to drop
columns_to_drop = ['id', 'user', 'tags', 'title',  'date_taken_minute', 'date_taken_hour', 'date_taken_day', 'date_taken_month', 'date_taken_year', 'date_upload_minute', 'date_upload_hour', 'date_upload_day', 'date_upload_month', 'date_upload_year', 'Unnamed: 16',	'Unnamed: 17',	'Unnamed: 18']
df_clustering = data_sample.drop(columns_to_drop , axis=1)

df_clustering.head()
# Out:
#               lat      long
# 123137  45.761939  4.826946
# 129307  45.778643  4.853103
# 187438  45.761079  4.832375
# 95079   45.760891  4.853900
# 22133   45.834753  4.833490

# %%
# we will keep only the lat and long columns for clustering

#Columns to drop
columns_to_drop = ['id', 'user', 'tags', 'title',  'date_taken_minute', 'date_taken_hour', 'date_taken_day', 'date_taken_month', 'date_taken_year', 'date_upload_minute', 'date_upload_hour', 'date_upload_day', 'date_upload_month', 'date_upload_year', 'Unnamed: 16',	'Unnamed: 17',	'Unnamed: 18']
df_clustering = data_sample.drop(columns_to_drop , axis=1)

df_clustering.head()
# Out:
#               lat      long
# 123137  45.761939  4.826946
# 129307  45.778643  4.853103
# 187438  45.761079  4.832375
# 95079   45.760891  4.853900
# 22133   45.834753  4.833490

# %%
# scaler
from sklearn.preprocessing import StandardScaler

# %%
# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_clustering)
# show
print(scaled_data)
# create a DataFrame
scaled_data_df = pd.DataFrame(data=scaled_data, columns=df_clustering.columns)
scaled_data_df.head()
# Out:
# [[-0.22474932 -0.40634547]
#  [ 0.35839415  0.42330679]
#  [-0.25477228 -0.23414751]
#  ...
#  [-1.30156089  3.52743752]
#  [-0.21441584 -0.54485873]
#  [-1.18237675 -0.79498824]]
#         lat      long
# 0 -0.224749 -0.406345
# 1  0.358394  0.423307
# 2 -0.254772 -0.234148
# 3 -0.261335  0.448586
# 4  2.317217 -0.198782

# %% [markdown]
# ## Task #2: Apply k-means Clustering and Find the Optimal Number of Clusters using Elbow Method

# %%
# k-means
from sklearn.cluster import KMeans

# %%
# number of clusters 
k = 3
# create a model
kmeans = KMeans(n_clusters=k, init='k-means++')
# fit scaled data
kmeans.fit(scaled_data_df)
# Out:
# KMeans(n_clusters=3)

# %%
# associated cluster labels
labels = kmeans.labels_
print(f"k-means labels: {labels}")
# Out:
# k-means labels: [184 175 156 ... 114  49 181]

# %%
# sum of squared distances
inertia = kmeans.inertia_
print(f"Sum of squared distances: {inertia}")
# Out:
# Sum of squared distances: 3453.39290075827

# %%
# ANSWER
# range of k
range_k = range(1, 200)
# a list of intertia scores
inertias = []

# vary k and apply k-means
for i in range_k:
    # apply k-means with i clusters
    kmeans = KMeans(n_clusters=i, init='k-means++')
    # fit scaled data 
    kmeans.fit(scaled_data_df)
    # append inertia to the list
    inertias.append(kmeans.inertia_)

# %%
# visualise
n = len(inertias)
xticks_new = np.arange(1, 200)
plt.plot(xticks_new, inertias, 'bx-')
plt.title('Finding the optimal number of clusters')
plt.xlabel('# clusters')
plt.ylabel('Sum of squared distances')
plt.show()

# %% [markdown]
# **RESULTS**
#
# * Add a column `cluster kmeans` to the `data_cleaned` DataFrame containing the labels of k-means clustering for `k=20`

# %%
# ANSWER
data_sample['k-means labels'] = labels

display(data_sample)
# Out:
#                  id           user        lat      long  \
# 123137  26674996493  136607346@N03  45.761939  4.826946
# 129307  30004369442  136607346@N03  45.778643  4.853103
# 187438  44433602344   75906220@N07  45.761079  4.832375
# 95079   15421567905   17727127@N00  45.760891  4.853900
# 22133    5619213266   22056213@N04  45.834753  4.833490
# ...             ...            ...        ...       ...
# 95577   15807010425   48551155@N05  45.767755  4.836225
# 113033  21135522632   34347356@N04  45.762543  4.827521
# 96475   11457042125   22789397@N05  45.731094  4.950969
# 8776     4796673651   37313543@N05  45.762235  4.822579
# 171160  44487137400  126667057@N02  45.734508  4.814693
#
#                                                      tags  \
# 123137  france,miniature,nikon,lyon,rhône,musée,nikkor...
# 129307  d5300,france,lyon,nikon,têtedor,fleur,nature,p...
# 187438       ail,stilllife,naturemorte,composition,garlic
# 95079                                                lyon
# 22133                    railways,frenchrailways,stefho74
# ...                                                   ...
# 95577   france,dance,europe,lyon,places,danse,hiphop,o...
# 113033  france,square,lyon,squareformat,rise,iphoneogr...
# 96475   japan,30,novembre,touch,01,convention,decembre...
# 8776    voyage,road,city,trip,france,monument,june,arc...
# 171160  labbez,monument,vue,paysage,fleuve,rhône,saone...
#
#                                                   title  date_taken_minute  \
# 123137        Musée du cinéma et de la miniature - Lyon               38.0
# 129307                             Parc de la Tête d'Or               54.0
# 187438                      Têtes d'ail blanc et violet               34.0
# 95079                                      Lyon2014_171               26.0
# 22133                                   BB 663901 INFRA               18.0
# ...                                                 ...                ...
# 95577                                           Hip Hop               45.0
# 113033                   150cl bottles of bad boy wine.               30.0
# 96475   Japan Touch - 2013-11-30- Eurexpo - Lyon - 8171               56.0
# 8776           Inside Basilique Notre Dame de Fourvière                1.0
# 171160                              architecture à Lyon               54.0
#
#         date_taken_hour  date_taken_day  date_taken_month  date_taken_year  \
# 123137               18              21                 5             2016
# 129307               16              15                 9             2016
# 187438               13               7                10             2018
# 95079                18              25                 9             2014
# 22133                 9              14                 4             2011
# ...                 ...             ...               ...              ...
# 95577                15              16                11             2014
# 113033               21               4                 9             2015
# 96475                17              30                11             2013
# 8776                  0              26                 5             2010
# 171160               15              24                11             2018
#
#         date_upload_minute  date_upload_hour  date_upload_day  \
# 123137                  45                11             27.0
# 129307                   5                 8              5.0
# 187438                  59                14              7.0
# 95079                   10                20              2.0
# 22133                   22                15             14.0
# ...                    ...               ...              ...
# 95577                   11                 1             17.0
# 113033                  30                22              4.0
# 96475                   37                 0             20.0
# 8776                    45                21             15.0
# 171160                  11                21             13.0
#
#         date_upload_month  date_upload_year  Unnamed: 16  Unnamed: 17  \
# 123137                  5            2016.0          NaN          NaN
# 129307                 10            2016.0          NaN          NaN
# 187438                 10            2018.0          NaN          NaN
# 95079                  10            2014.0          NaN          NaN
# 22133                   4            2011.0          NaN          NaN
# ...                   ...               ...          ...          ...
# 95577                  11            2014.0          NaN          NaN
# 113033                  9            2015.0          NaN          NaN
# 96475                  12            2013.0          NaN          NaN
# 8776                    7            2010.0          NaN          NaN
# 171160                 12            2018.0          NaN          NaN
#
#         Unnamed: 18  k-means labels
# 123137          NaN             184
# 129307          NaN             175
# 187438          NaN             156
# 95079           NaN             154
# 22133           NaN             180
# ...             ...             ...
# 95577           NaN             139
# 113033          NaN             184
# 96475           NaN             114
# 8776            NaN              49
# 171160          NaN             181
#
# [5000 rows x 20 columns]

# %% [markdown]
# ## Task #3: Cluster Evaluation using Silhouette Coefficient

# %%
# silhouette scores
from sklearn.metrics import silhouette_score, silhouette_samples

# %%
# ANSWER
# Calculate silhouette scores
silhouette_avg = silhouette_score(scaled_data, labels, metric='euclidean')
sample_silhouette_values = silhouette_samples(scaled_data, labels, metric='euclidean')
data_sample['silhouette kmeans'] = sample_silhouette_values

print(f"Average silhouette score: {silhouette_avg}")
print(f"Sample Silhouette values: {sample_silhouette_values}")
# Out:
# Average silhouette score: 0.5613695312484764
# Sample Silhouette values: [0.39071737 0.157049   0.46945412 ... 0.66175991 0.57764601 0.43052503]

# %%
# ANSWER
def plot_silhouette(sample_silhouette_values, silhouette_avg, labels, n_clusters=3):
    # Create the plot
    fig = plt.figure(figsize=(10, 6))
    
    y_lower = 10
    for i in range(n_clusters):
        # Get silhouette scores for cluster i
        ith_cluster_values = sample_silhouette_values[labels == i]
        ith_cluster_values.sort()
        
        size_cluster_i = ith_cluster_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        # Fill the silhouette
        plt.fill_betweenx(np.arange(y_lower, y_upper),
                         0, ith_cluster_values,
                         alpha=0.7)
        
        # Label the silhouette plots
        plt.text(-0.05, y_lower + 0.5 * size_cluster_i, f'Cluster {i}')
        
        y_lower = y_upper + 10
    
    # Add vertical line for average silhouette score
    plt.axvline(x=silhouette_avg, color='red', linestyle='--', 
                label=f'Average Silhouette: {silhouette_avg:.3f}')
    
    plt.title('Silhouette Plot')
    plt.xlabel('Silhouette Coefficient')
    plt.ylabel('Cluster')
    plt.legend(loc='best')
    plt.tight_layout()
    
    return fig
