# %%
import pandas as pd
import folium

df = pd.read_table("data/cleaned-data.csv", sep=",")

sampled_data = df.sample(2000)

m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

for i in range(0,len(sampled_data)):
    folium.Marker(
      location=[sampled_data.iloc[i]['lat'], sampled_data.iloc[i]['long']],
      popup=sampled_data.iloc[i]['id'],
   ).add_to(m)
    
m.save("maps/map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_339ff03a59e8cd90c65b147b274007dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_339ff03a59e8cd90c65b147b274007dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_339ff03a59e8cd90c65b147b274007dd = L.map(
#                 &quot;map_339ff03a59e8cd90c65b147b274007dd&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f165881a743b55d3efac9075c2130d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f165881a743b55d3efac9075c2130d2.addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#             var marker_ae8ce4145306ba62ef5f5d3fc045e727 = L.marker(
#                 [45.83741, 4.826163],
#                 {
# }
#             ).addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#         var popup_7fbe385060be5873569a24f3556845df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43541ecab494c880171f7315fd5a9c22 = $(`&lt;div id=&quot;html_43541ecab494c880171f7315fd5a9c22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9267393091&lt;/div&gt;`)[0];
#                 popup_7fbe385060be5873569a24f3556845df.setContent(html_43541ecab494c880171f7315fd5a9c22);
#
#
#
#         marker_ae8ce4145306ba62ef5f5d3fc045e727.bindPopup(popup_7fbe385060be5873569a24f3556845df)
#         ;
#
#
#
#
#             var marker_146408298e248fde80d4fd5e8d793bc6 = L.marker(
#                 [45.83744, 4.826388],
#                 {
# }
#             ).addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#         var popup_1ec7fcbf8f95d91d0c2d1fd4234ebb43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fd1e60ac3e54db0b6c8f8086a5dc4d9 = $(`&lt;div id=&quot;html_3fd1e60ac3e54db0b6c8f8086a5dc4d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;35361759396&lt;/div&gt;`)[0];
#                 popup_1ec7fcbf8f95d91d0c2d1fd4234ebb43.setContent(html_3fd1e60ac3e54db0b6c8f8086a5dc4d9);
#
#
#
#         marker_146408298e248fde80d4fd5e8d793bc6.bindPopup(popup_1ec7fcbf8f95d91d0c2d1fd4234ebb43)
#         ;
#
#
#
#
#             var marker_fe35fa8a79520cc7cfa5fd6b1e44d9bb = L.marker(
#                 [45.752929, 4.822086],
#                 {
# }
#             ).addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#         var popup_64791e0195f6101857875322f67818f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e92de4710f1719715d240d813516c6d4 = $(`&lt;div id=&quot;html_e92de4710f1719715d240d813516c6d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;37096973356&lt;/div&gt;`)[0];
#                 popup_64791e0195f6101857875322f67818f5.setContent(html_e92de4710f1719715d240d813516c6d4);
#
#
#
#         marker_fe35fa8a79520cc7cfa5fd6b1e44d9bb.bindPopup(popup_64791e0195f6101857875322f67818f5)
#         ;
#
#
#
#
#             var marker_ad7fa351ca75942e54c31fbc453dfd72 = L.marker(
#                 [45.83741, 4.826163],
#                 {
# }
#             ).addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#         var popup_b831ab7cceabe3d56c478b637eb23b6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06dcb9bb078e98e381ec2ce0206f5a58 = $(`&lt;div id=&quot;html_06dcb9bb078e98e381ec2ce0206f5a58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10923638675&lt;/div&gt;`)[0];
#                 popup_b831ab7cceabe3d56c478b637eb23b6c.setContent(html_06dcb9bb078e98e381ec2ce0206f5a58);
#
#
#
#         marker_ad7fa351ca75942e54c31fbc453dfd72.bindPopup(popup_b831ab7cceabe3d56c478b637eb23b6c)
#         ;
#
#
#
#
#             var marker_c42a205121b8d73f11f5125338d13967 = L.marker(
#                 [45.777418, 4.831036],
#                 {
# }
#             ).addTo(map_339ff03a59e8cd90c65b147b274007dd);
#
#
#         var popup_7b772da4a707d6ed1a8cd3fb51ac2c78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb0b7b74f6d68839ad010e829854d2ee = $(`&lt;div id=&quot;html_eb0b7b74f6d68839ad010e829854d2ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;14699699164&lt;/div&gt;`)[0];
#                 popup_7b772da4a707d6ed1a8cd3fb51ac2c78.setContent(html_eb0b7b74f6d68839ad010e829854d2ee);
#
#
#
#         marker_c42a205121b8d73f11f5125338d13967.bindPopup(popup_7b772da4a707d6ed1a8cd3fb51ac2c78)
#         ;
#
#
#
#
#             var marker_ef3c7503802369a45988992a028a7e41 = L.marker(
#                 [45.768361, 4.830025],
#                 {
# }
#             ).addTo(map_339
